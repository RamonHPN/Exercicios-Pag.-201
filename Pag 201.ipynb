# %% [markdown]
# EXERCICIOS PROCESSADORES
#
# Aluno: Ramon Henrique Pereira Neves
# Professor: Claudomiro Sales

# %% [markdown]
# 1) Descreva as funções básicas de uma UCP, indicando os seus componentes principais.

# %% [markdown]
# As principais funções da UCP unidade central de processamento são:
#
# 1 - Busca de uma instrução na memória;
#
# 2 - Interpretação de uma instrução;
#
# 3 - Execução de uma operação representada na instrução;
#
# 4 - Gravação de eventuais resultados do processamento;
#
# 5 - Reinicia todo o processo (caso seja necessário)

# %% [markdown]
# 2) Quais são as funções da unidade aritmética e lógica - ULA?

# %% [markdown]
# A principal função da unidade lógica aritmética e fazer as principais operações do computador que conhecemos hoje, ou seja, ela soma, subtraí, multiplica, e por fim divide além de determinar se um número e positivo e negativo. Já as funções da ULA são as portas lógicas: AND, OR, XOR, NOT, complemento, deslocamento a direita e esquerda, incremento de 1 e também o decremento de 1.

# %% [markdown]
# 5) Quais são as funções da unidade de controle de um processador?

# %% [markdown]
# A unidade de controle (UC) assume todas as tarefas de controle das ações a serem executadas pelo computador, comandando todos os demais componentes de sua arquitetura, ou seja, é a UC que deve garantir a execução correta dos programas e a utilização dos dados corretos nas operações que as manipulam.

# %% [markdown]
# 6) Seria possível realizar o projeto de um processador em que o tamanho em bits do CI fosse diferente do tamanho do REM nesse caso, qual dos dois registradores deveria ter maior tamanho? Por que?

# %% [markdown]
# Não seria possível pois as instruções e dados ocupam a mesma memória. Ambos os registradores armazenam o mesmo endereço e devem continuar do mesmo tamanho.

# %% [markdown]
# 7) Considere um computador cuja MP e organizada com N células de 1 byte cada uma. As instruções interpretadas pela UCP possuem três tamanhos diferentes: as do tipo A possuem 16 bits; as do tipo B possuem 32 bits e as do tipo C possuem 48 bits. Considerando que o código de operação de cada uma tem uma tamanho fixo e igual a 8 bits e que os programas executados nesse processador são constituídos de uma mistura dos três tipos de instruções, imagine um processo prático para incremento automático do CI após a execução de cada instrução de um programa.

# %%
#COP = 8 bits
COP = 2**8 
print(COP)
x = 0
i = 0
for i in range(COP-172):
    x +=1
print(x)
print("COP entre 0 e 84: Instruções de 16 bits de tamanho (CI <- CI + 2) após a busca dessa instrução.")
y = 0
for i in range(COP-86):
    y +=1
print(y)
print("COP entre 85 e 170: Instruções de 32 bits de tamanho (CI <- CI + 4) após a busca dessa instrução.")
w=0
for i in range(COP-1):
    w +=1
print(w)
print("COP 171 A 255: Instruções de 48 bits de tamanho (CI <- CI + 6) após a busca da instrução.")
# Out:
# 256
# 84
# COP entre 0 e 84: Instruções de 16 bits de tamanho (CI <- CI + 2) após a busca dessa instrução.
# 170
# COP entre 85 e 170: Instruções de 32 bits de tamanho (CI <- CI + 4) após a busca dessa instrução.
# 255
# COP 171 A 255: Instruções de 48 bits de tamanho (CI <- CI + 6) após a busca da instrução.

# %% [markdown]
# 8) Considere um processador cujo ciclo de instruções não possua a etapa de incremento automático do valor do CI. Imagine um método alternativo que permita a execução do programa.

# %% [markdown]
# Utilizando a inspeção de campo “código de operação”. Caso ele não seja um desvio, fazer a busca no endereço seguinte (ou em N endereços seguintes, dependendo do valor do campo). Caso contrário utilizar o campo “operando” como endereço da próxima instrução

# %% [markdown]
# 9) Qual é e onde se localiza o registrador cujo conteúdo controla a sequência de processamento das instruções de um programa?

# %% [markdown]
# Contador de instruções (CI) e se localiza na UCP.

# %% [markdown]
# 10) considerando as instruções a seguir, indique a quantidade de ciclos de memória despendidos para realizar seu ciclo de instruções completo (explicite a quantidade de ciclos de leitura e de escrita, quando dor o caso):

# %% [markdown]
# ![a2.PNG](attachment:98679d91-3c70-403a-88b8-ad2773d237d4.PNG)

# %% [markdown]
# R:
#
# ADD op ACC 1L + <= 1L = 2 (OP.) Ciclos
#
# SUB op ACC 1L + <= ACC- 1L = 2 (OP.) Ciclos
#
# ADD op.1, op.2 (op.1) 1l + <= (op.1) + 2l + 1e = 4 (op.2) Ciclos
#
# INCR ACC 1L = 1 <= ACC + 1 CICLO
#
# LDA op. ACC = 1l + (op.) 1l = 2 ciclos

# %% [markdown]
# 11) Qual é o registrador cujo conteúdo determina a capacidade de memória de um computador? Justifique.
#
# REM – registrador de endereços de memória. Está ligado diretamente a barra de endereços que por sua vez, está ligada a memória principal.

# %% [markdown]
# 12) considere um computador com 64K células de memória, instruções de um operando, tendo possibilidade de ter 256 instruções de máquina. Considerando que cada instrução tem o tamanho de uma célula, que é o mesmo tamanho da palavra do sistema, que tamanho, em bits, do Reg. CI e RDM? Qual é o total de bits dessa memória?
#
# Reg = 24 bits; CI = 16 bits; RDM = 24 bits.
#
# Total de bits = 1.5 Mbits.

# %% [markdown]
# 13) Um computador tem um REM de 16 bits e um barramento de dados de 20 bits. Possui instruções de um operando, todas do tamanho de uma célula de memória e do mesmo tamanho da palavra. Ele foi adquirido com apenas uma placa de 4K de memória.
#
# PERGUNTA-SE
#
# a) Qual o tamanho em bits do RDM e do CI?

# %%
BD = 20
RDM = BD 
REM = 16  
CI = REM
print("RDM =",RDM,"bits e CI =",CI,"bits")
# Out:
# RDM = 20 bits e CI = 16 bits

# %% [markdown]
# b) Seria possível aumentar-se a capacidade de armazenamento dessa memória? Até quanto? E por quê?
#
# Sim, pois o processador suporta até 64K
#
# c) Qual a quantidade máxima de instruções de máquina que poderia existir nesse computador?
#
# REM = 16 bits = 16 instruções de maquina

# %% [markdown]
# 14) Um computador possui um conjunto de 128 instruções de um operando: supondo que sua memória tenha capacidade de armazenar 512 palavras e que cada instrução tenha o tamanho de uma palavra e da célula da memória. Pergunta-se
#
# a) Qual o tamanho em bits do REM, RDM, RI E CI?

# %%
import math
palavra = 512
CI = math.log(palavra,2)
REM = CI
print(REM,CI,"bits")
# Out:
# 9.0 9.0 bits

# %%
x = 128 
RDM = RI = math.log(x,2) + 9
print(RDM,RI,"bits")
# Out:
# 16.0 16.0 bits

# %% [markdown]
# b) Qual a capacidade da memória, em bytes?

# %%
N = 512 * 2048 
print(N/2**20,"K")
# Out:
# 1.0 K

# %% [markdown]
# c) Se quisesse alterar o tamanho das instruções para 17 bits, mantendo inalterado o tamanho do REM, quantas novas instruções poderiam ser criadas?
#
# Alterando o número do C.op. de 7 para 8, Logo, 9 + 8 = 17
# Assim, 2**8 = 512 conjuntos de instruções

# %% [markdown]
# 15) Quando se fala que um determinado microprocessador A é um micro de 8 bits e que um outro micro B é de 16 bits, a que estamos nos referindo? Ao tamanho da célula de MP ou ao tamanho da palavra? Qual a base desses dois conceitos (palavra e célula?)
#
# Se refere ao tamanho da palavra, pois é a quantidade máxima de bits que o processador pode
# Computar por vez, assim, quanto mais bits a palavra tem, mais eficiente o processador.

# %% [markdown]
# 16) Considere um computador que possua uma UCP com CI de 16 bits e RI de 38 bits. Suas instruções têm dois operandos do mesmo tamanho (16 bits), além, é claro, de um código de operação.
# Pergunta-se:
#
# a) Qual o tamanho da instrução?
#
# RI = 38 bits

# %% [markdown]
# b) Qual o tamanho do campo do código de operação?

# %%
COP = (38 - 16 - 16) 
print(COP," bits")
# Out:
# 6  bits

# %% [markdown]
# c) Considerando que a configuração básica dessa máquina é de 16 Kbytes de memória, até que tamanho pode a memória ser expandida?

# %%
Tamanho = 2**10 * 2**6 
print("Pode ser expandida até ",Tamanho," bits")
# Out:
# Pode ser expandida até  65536  bits

# %% [markdown]
# 17) A figura a seguir ilustra uma memória de 256 células em que cada célula (ou palavra) contém 16 bits. Nessa figura, cada retângulo simboliza uma célula de memória; o número hexadecimal que está dentro do retângulo representa o seu conteúdo, e o número colocado ao lado de cada um indica o endereço da célula (retângulo).

# %% [markdown]
#  ![a.PNG](attachment:55f0c25d-ccb9-476c-9ae8-34026c9fbb8d.PNG)

# %% [markdown]
# Pergunta-se:
#
# a) Qual a capacidade total da memória, em bits?

# %%
R = 256 * 16 
print(R,"bits")
# Out:
# 4096 bits

# %% [markdown]
# b) Supondo que, no início de um ciclo de instrução, o conteúdo do CI (contador de instrução) seja o hexadecimal A5 e que cada instrução ocupe uma única célula (palavra), qual será a instrução que será executada?
#
#  CB06

# %% [markdown]
# c) Supondo que o conteúdo do REM (registrador de endereços de memória) tenha o valor hexadecimal FD e que um sinal de leitura seja enviado da UCP para a memória, qual deverá ser o conteúdo do RDM (registrador de dados de memória) ao final do ciclo de leitura?
#
# 4040

# %% [markdown]
# 18) Explique a diferença entre um processamento sequencial e um outro pipeline.
#
# O processo só executa uma instrução por vez, ou seja, espera uma instrução finalizar para começar outra, já o processo pipeline, cada ciclo de instruções são executados independentemente uma da outra, ou seja, enquanto um ciclo do meio de uma instrução está sendo executado, o ciclo do início de outra instrução está sendo iniciado, assim podendo ter vários processos rolando ao mesmo tempo.

# %% [markdown]
# 19) Considere um processador que possua um CI com largura de 32 bits e tenha um conjunto de 61 instruções todas de tamanho fixo igual a 32 bits; o processador é, ainda, constituído de 60 registradores de dados para armazenamento de valores inteiros, todos com 32 bits de largura e 20 registradores de 64 bits de largura para armazenamento de valores em ponto flutuante. Considere que todas as instruções que manipulam operações matemáticas têm um formato de 2 operandos.
#
# Pergunta-se:

# %% [markdown]
# a) Qual é o total de bits da largura de cada campo operando das instruções matemáticas?
#
# 32 bits

# %% [markdown]
# b) Qual é o valor do espaço de endereçamento da memória desse sistema?

# %%
CI = 32
REM = 2 ** CI 
print(REM/2**30,"GB")
# Out:
# 4.0 GB

# %% [markdown]
# c) Considerando as instruções que manipulam com dados armazenados em registradores, indique qual deverá ser a largura mínima do endereçamento dos registradores de inteiros.
#
# 32 bits

# %% [markdown]
# 20) Considere um processador que possua um conjunto de 197 instruções, algumas das quais têm formato de 2 operandos, com32 bits de largura e outras possuem formato de 1 operando, com24 bits de largura. Explique como deve ser a organização de entrada e saída do decodificador de instruções desse processador.

# %% [markdown]
# Os bits para endereçar 197 instruções são 8, pois 2**8 = 256, logo entra 8 bits no decodificador e sai uma das 197 instruções.

# %% [markdown]
# 22) Considere um processador que possua um conjunto de instruções sobre o qual foi feito um extrato das mais importantes na tabela a seguir. Neste processador todos os endereços possuem 16 bits e as instruções possuem um formato único, mostrado a seguir, e ele possui um conjunto de 16 registradores de dados. Suponha que em um determinado instante, correspondente ao término da execução de uma instrução qualquer, o Cl tenha armazenado o seguinte valor, representado em hexadecimal: CI = 2B78, e que o registrador RI tenha armazenado o seguinte valor em hexadecimal: RI = 2C4FO8D9.

# %% [markdown]
# ![a1.PNG](attachment:48e4b919-72c8-421c-bb23-0f9d220c711e.PNG)

# %% [markdown]
# Pergunta-se:
#
# a) Qual deverá ser a largura, em bits, do campo C.Op. das instruções?

# %%
RI = 32 - 16 - 4 
print(RI,"bits")
# Out:
# 12 bits

# %% [markdown]
# b) Qual deverá ser a largura do campo Reg das instruções?

# %%
import math
E = 16
RI = math.log(E,2)
print(RI,"bits")
# Out:
# 4.0 bits

# %% [markdown]
# c) Quantos acessos à memória devem ser realizados para executar o ciclo completo da instrução de C.OP. iguala 11? E para a instrução de C.OP. igual a 21?
#
# C.OP = 11 ---- 1 acesso
#
# C.OP = 21 ---- 2 acesso
